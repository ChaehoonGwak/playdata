# %%
def balance(N):
    cnt = 0
    coin = [500, 100, 50, 10]
    
    for i in coin:
        cnt += N // i
        N %= i
        
    return cnt

print(balance(1260))
# Out:
# 6

# %%
a = [100, 500, 50, 10]

# %%
a.sort(reverse=True)

# %%
a
# Out:
# [500, 100, 50, 10]

# %%
#판다스

# %%
import pandas as pd

# %%
a = pd.Series({'a' : 1, 'b' : 2, 'c' : 3})

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
a.index
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
a.values
# Out:
# array([1, 2, 3], dtype=int64)

# %%
b = pd.Series(['2021-09-08', 3.14, 'ABC'])

# %%
b.values
# Out:
# array(['2021-09-08', 3.14, 'ABC'], dtype=object)

# %%
import numpy as np

# %%
np.array((['a23432', 'b']))
# Out:
# array(['a23432', 'b'], dtype='<U6')

# %%
kbo = pd.read_csv("./kbo.csv")

# %%
kbo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 857 entries, 0 to 856
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   선수명     857 non-null    object
#  1   등번호     829 non-null    float64
#  2   생년월일    857 non-null    object
#  3   포지션     857 non-null    object
#  4   신장/체중   857 non-null    object
#  5   경력      853 non-null    object
#  6   입단 계약금  733 non-null    object
#  7   연봉      856 non-null    object
#  8   지명순위    856 non-null    object
#  9   입단년도    709 non-null    object
# dtypes: float64(1), object(9)
# memory usage: 67.1+ KB

# %%
kbo.head(1)
# Out:
#    선수명   등번호           생년월일       포지션       신장/체중                    경력  \
# 0  강동연  21.0  1992년 12월 18일  투수(우투우타)  195cm/94kg  진북초-덕수중-유신고-두산-상무-두산
#
#   입단 계약금      연봉        지명순위  입단년도
# 0    NaN  4400만원  11 두산 육성선수  12두산

# %%
kbo.tail()
# Out:
#      선수명   등번호           생년월일        포지션        신장/체중                   경력  \
# 852  하주석  16.0  1994년 02월 25일  내야수(우투좌타)   184cm/84kg    강남초-덕수중-신일고-한화-상무
# 853  한승주  59.0  2001년 03월 17일   투수(우투우타)   184cm/82kg        부산수영초-대천중-부산고
# 854  허관회  26.0  1999년 02월 12일   포수(우투우타)   176cm/83kg  경동초(의정부리틀)-건대부중-경기고
# 855  황영국  60.0  1995년 12월 26일   투수(좌투좌타)   185cm/83kg  청주우암초-청주중-청주고-한화-경찰
# 856   힐리   NaN  1992년 01월 10일  내야수(우투우타)  195cm/104kg      미국 Oregon(대)-한화
#
#        입단 계약금        연봉                지명순위  입단년도
# 852   30000만원   13500만원      12 한화 1라운드 1순위  12한화
# 853   11000만원    3000만원  20 한화 2차 2라운드 18순위  20한화
# 854    3000만원    3100만원  19 한화 2차 9라운드 83순위  20한화
# 855   20000만원    3300만원            14 한화 1차  14한화
# 856  300000달러  500000달러          21 한화 자유선발  21한화

# %%
type(kbo.loc[856, '등번호'])
# Out:
# numpy.float64

# %%
NaN -> Missing value
결측치

결측치 -> NaN, None
# Out:
#   File "<ipython-input-16-0b8982fe0635>", line 1
#     NaN -> Missing value
#         ^
# SyntaxError: invalid syntax

# %%
kbo.isnull().sum()

# %%
np_a = np.arange(1,13).reshape(4,3)

# %%
np_a.shape
# Out:
# (4, 3)

# %%
np_a.ndim
# Out:
# 2

# %%
np_a[0,0]
# Out:
# 1

# %%
np_a[-1,-1]
# Out:
# 12

# %%
np_a[np_a > 5]
# Out:
# array([ 6,  7,  8,  9, 10, 11, 12])

# %%
import random

# %%
random.seed(42)
np_b =np.array([random.random() for x in range(30)]).reshape(6,5)

# %%
np_b
# Out:
# array([[0.6394268 , 0.02501076, 0.27502932, 0.22321074, 0.73647121],
#        [0.67669949, 0.89217957, 0.08693883, 0.42192182, 0.02979722],
#        [0.21863797, 0.50535529, 0.02653597, 0.19883765, 0.64988444],
#        [0.54494148, 0.22044062, 0.58926568, 0.80943046, 0.00649876],
#        [0.80581925, 0.69813939, 0.34025052, 0.1554795 , 0.95721307],
#        [0.33659455, 0.09274584, 0.09671638, 0.84749437, 0.60372603]])

# %%
np_b[:3,3:]
# Out:
# array([[0.22321074, 0.73647121],
#        [0.42192182, 0.02979722],
#        [0.19883765, 0.64988444]])

# %%
np_b[1:,2:4]
# Out:
# array([[0.08693883, 0.42192182],
#        [0.02653597, 0.19883765],
#        [0.58926568, 0.80943046],
#        [0.34025052, 0.1554795 ],
#        [0.09671638, 0.84749437]])

# %%
# iloc, loc

# %%
# i -> index 번호(이름 x)
kbo.iloc[1,7]
# Out:
# '12000만원'

# %%
kbo.loc[1, ['생년월일', '연봉']]
# Out:
# 생년월일    1993년 10월 19일
# 연봉            12000만원
# Name: 1, dtype: object

# %%
kbo.head()
# Out:
#    선수명   등번호           생년월일        포지션       신장/체중                    경력  \
# 0  강동연  21.0  1992년 12월 18일   투수(우투우타)  195cm/94kg  진북초-덕수중-유신고-두산-상무-두산
# 1  강진성  49.0  1993년 10월 19일  내야수(우투우타)  180cm/81kg     가동초-잠신중-경기고-NC-경찰
# 2  강태경  78.0  2001년 07월 26일   투수(우투좌타)  188cm/95kg           양덕초-잠실중-배명고
# 3  구창모  59.0  1997년 02월 17일   투수(좌투좌타)  183cm/85kg        천안남산초-덕수중-울산공고
# 4  권법수  65.0  1997년 04월 05일  외야수(우투우타)  183cm/82kg          선학초-재능중-제물포고
#
#     입단 계약금       연봉                지명순위  입단년도
# 0      NaN   4400만원          11 두산 육성선수  12두산
# 1   7000만원  12000만원     12 NC 4라운드 33순위  12NC
# 2   7000만원   3000만원  20 NC 2차 5라운드 41순위  21NC
# 3  15000만원  25000만원   15 NC 2차 1라운드 3순위  15NC
# 4   5000만원   3000만원  17 NC 2차 6라운드 58순위  17NC

# %%
kbo.loc[1:3, '포지션':'입단년도']
# Out:
#          포지션       신장/체중                 경력   입단 계약금       연봉  \
# 1  내야수(우투우타)  180cm/81kg  가동초-잠신중-경기고-NC-경찰   7000만원  12000만원
# 2   투수(우투좌타)  188cm/95kg        양덕초-잠실중-배명고   7000만원   3000만원
# 3   투수(좌투좌타)  183cm/85kg     천안남산초-덕수중-울산공고  15000만원  25000만원
#
#                  지명순위  입단년도
# 1     12 NC 4라운드 33순위  12NC
# 2  20 NC 2차 5라운드 41순위  21NC
# 3   15 NC 2차 1라운드 3순위  15NC

# %%
kbo.set_index('선수명', inplace=True)

# %%
kbo.loc[['강진성','구창모'], '신장/체중':'연봉']
# Out:
#           신장/체중                 경력   입단 계약금       연봉
# 선수명
# 강진성  180cm/81kg  가동초-잠신중-경기고-NC-경찰   7000만원  12000만원
# 구창모  183cm/85kg     천안남산초-덕수중-울산공고  15000만원  25000만원

# %%
kbo.loc[['강진성','구창모'], ['신장/체중','연봉']]
# Out:
#           신장/체중       연봉
# 선수명
# 강진성  180cm/81kg  12000만원
# 구창모  183cm/85kg  25000만원

# %%
kbo.iloc[[1,3], 3:7]
# Out:
#           신장/체중                 경력   입단 계약금       연봉
# 선수명
# 강진성  180cm/81kg  가동초-잠신중-경기고-NC-경찰   7000만원  12000만원
# 구창모  183cm/85kg     천안남산초-덕수중-울산공고  15000만원  25000만원

# %%
kbo.reset_index(inplace=True)

# %%
kbo['포지션'].unique()
# Out:
# array(['투수(우투우타)', '내야수(우투우타)', '투수(우투좌타)', '투수(좌투좌타)', '외야수(우투우타)',
#        '외야수(우투좌타)', '포수(우투우타)', '내야수(우투양타)', '내야수(우투좌타)', '외야수(좌투좌타)',
#        '투수(우언우타)', '투수(우언양타)', '투수(좌투우타)', '외야수(우투양타)', '포수(우투좌타)',
#        '투수(우언좌타)', '내야수(좌투좌타)', '투수(우투양타)', '투수(좌언좌타)'], dtype=object)

# %%
kbo['포지션'].value_counts()
# Out:
# 투수(우투우타)     265
# 내야수(우투우타)    121
# 투수(좌투좌타)     104
# 내야수(우투좌타)     66
# 포수(우투우타)      65
# 외야수(우투우타)     62
# 외야수(우투좌타)     48
# 외야수(좌투좌타)     34
# 투수(우언우타)      31
# 투수(우투좌타)      28
# 포수(우투좌타)      11
# 내야수(좌투좌타)      9
# 투수(좌투우타)       3
# 투수(우투양타)       2
# 외야수(우투양타)      2
# 투수(우언양타)       2
# 내야수(우투양타)      2
# 투수(우언좌타)       1
# 투수(좌언좌타)       1
# Name: 포지션, dtype: int64

# %%
#파생변수

# %%
def myfunc(x):
    return x.split("/")[0]

# %%
kbo['신장'] = kbo ['신장/체중'].apply(myfunc)

# %%
kbo
# Out:
#      선수명   등번호           생년월일        포지션        신장/체중                    경력  \
# 0    강동연  21.0  1992년 12월 18일   투수(우투우타)   195cm/94kg  진북초-덕수중-유신고-두산-상무-두산
# 1    강진성  49.0  1993년 10월 19일  내야수(우투우타)   180cm/81kg     가동초-잠신중-경기고-NC-경찰
# 2    강태경  78.0  2001년 07월 26일   투수(우투좌타)   188cm/95kg           양덕초-잠실중-배명고
# 3    구창모  59.0  1997년 02월 17일   투수(좌투좌타)   183cm/85kg        천안남산초-덕수중-울산공고
# 4    권법수  65.0  1997년 04월 05일  외야수(우투우타)   183cm/82kg          선학초-재능중-제물포고
# ..   ...   ...            ...        ...          ...                   ...
# 852  하주석  16.0  1994년 02월 25일  내야수(우투좌타)   184cm/84kg     강남초-덕수중-신일고-한화-상무
# 853  한승주  59.0  2001년 03월 17일   투수(우투우타)   184cm/82kg         부산수영초-대천중-부산고
# 854  허관회  26.0  1999년 02월 12일   포수(우투우타)   176cm/83kg   경동초(의정부리틀)-건대부중-경기고
# 855  황영국  60.0  1995년 12월 26일   투수(좌투좌타)   185cm/83kg   청주우암초-청주중-청주고-한화-경찰
# 856   힐리   NaN  1992년 01월 10일  내야수(우투우타)  195cm/104kg       미국 Oregon(대)-한화
#
#        입단 계약금        연봉                지명순위  입단년도     신장
# ...

# %%
kbo['체중'] = kbo ['신장/체중'].apply(lambda x:x.split("/")[1])

# %%
kbo
# Out:
#      선수명   등번호           생년월일        포지션        신장/체중                    경력  \
# 0    강동연  21.0  1992년 12월 18일   투수(우투우타)   195cm/94kg  진북초-덕수중-유신고-두산-상무-두산
# 1    강진성  49.0  1993년 10월 19일  내야수(우투우타)   180cm/81kg     가동초-잠신중-경기고-NC-경찰
# 2    강태경  78.0  2001년 07월 26일   투수(우투좌타)   188cm/95kg           양덕초-잠실중-배명고
# 3    구창모  59.0  1997년 02월 17일   투수(좌투좌타)   183cm/85kg        천안남산초-덕수중-울산공고
# 4    권법수  65.0  1997년 04월 05일  외야수(우투우타)   183cm/82kg          선학초-재능중-제물포고
# ..   ...   ...            ...        ...          ...                   ...
# 852  하주석  16.0  1994년 02월 25일  내야수(우투좌타)   184cm/84kg     강남초-덕수중-신일고-한화-상무
# 853  한승주  59.0  2001년 03월 17일   투수(우투우타)   184cm/82kg         부산수영초-대천중-부산고
# 854  허관회  26.0  1999년 02월 12일   포수(우투우타)   176cm/83kg   경동초(의정부리틀)-건대부중-경기고
# 855  황영국  60.0  1995년 12월 26일   투수(좌투좌타)   185cm/83kg   청주우암초-청주중-청주고-한화-경찰
# 856   힐리   NaN  1992년 01월 10일  내야수(우투우타)  195cm/104kg       미국 Oregon(대)-한화
#
# ...

# %%
kbo.drop(['신장/체중'], axis=1, inplace=True)

# %%
kbo['신장']
# Out:
# 0      195cm
# 1      180cm
# 2      188cm
# 3      183cm
# 4      183cm
#        ...
# 852    184cm
# 853    184cm
# 854    176cm
# 855    185cm
# 856    195cm
# Name: 신장, Length: 857, dtype: object

# %%
kbo[['신장', '체중']]
# Out:
#         신장     체중
# 0    195cm   94kg
# 1    180cm   81kg
# 2    188cm   95kg
# 3    183cm   85kg
# 4    183cm   82kg
# ..     ...    ...
# 852  184cm   84kg
# 853  184cm   82kg
# 854  176cm   83kg
# 855  185cm   83kg
# 856  195cm  104kg
#
# [857 rows x 2 columns]

# %%
kbo['신장'] = kbo ['신장'].apply(lambda x: int(x.replace('cm', '')))
kbo['체중'] = kbo ['체중'].apply(lambda x: int(x.replace('kg', '')))

# %%
kbo
# Out:
#      선수명   등번호           생년월일        포지션                    경력    입단 계약금  \
# 0    강동연  21.0  1992년 12월 18일   투수(우투우타)  진북초-덕수중-유신고-두산-상무-두산       NaN
# 1    강진성  49.0  1993년 10월 19일  내야수(우투우타)     가동초-잠신중-경기고-NC-경찰    7000만원
# 2    강태경  78.0  2001년 07월 26일   투수(우투좌타)           양덕초-잠실중-배명고    7000만원
# 3    구창모  59.0  1997년 02월 17일   투수(좌투좌타)        천안남산초-덕수중-울산공고   15000만원
# 4    권법수  65.0  1997년 04월 05일  외야수(우투우타)          선학초-재능중-제물포고    5000만원
# ..   ...   ...            ...        ...                   ...       ...
# 852  하주석  16.0  1994년 02월 25일  내야수(우투좌타)     강남초-덕수중-신일고-한화-상무   30000만원
# 853  한승주  59.0  2001년 03월 17일   투수(우투우타)         부산수영초-대천중-부산고   11000만원
# 854  허관회  26.0  1999년 02월 12일   포수(우투우타)   경동초(의정부리틀)-건대부중-경기고    3000만원
# 855  황영국  60.0  1995년 12월 26일   투수(좌투좌타)   청주우암초-청주중-청주고-한화-경찰   20000만원
# 856   힐리   NaN  1992년 01월 10일  내야수(우투우타)       미국 Oregon(대)-한화  300000달러
#
#            연봉                지명순위  입단년도   신장   체중
# ...

# %%
#
kbo['BMI'] = kbo['체중'] / (kbo['신장'] * 0.01) ** 2

# %%
kbo.sort_values(by='BMI', ascending=False)
# Out:
#      선수명   등번호           생년월일        포지션                          경력   입단 계약금  \
# 256  한기원  85.0  1998년 03월 10일  내야수(우투우타)               부산중앙초-부산중-부산고   3000만원
# 396  양기현  55.0  1998년 12월 16일   투수(우투우타)               서울청구초-홍은중-장충고   9000만원
# 571  이대호  10.0  1982년 06월 21일  내야수(우투우타)      부산수영초-대동중-경남고-(영남사이버대)  21000만원
# 799  박주홍  41.0  1999년 08월 20일   투수(좌투좌타)             광주서석초-충장중-광주제일고  10000만원
# 122  백민규  65.0  1998년 01월 22일  내야수(우투우타)                 도산초-현일중-장안고   4000만원
# ..   ...   ...            ...        ...                         ...      ...
# 210  백선기  94.0  1998년 08월 27일  외야수(좌투좌타)               남도초-경상중-대구상원고   5000만원
# 599  강한울   6.0  1991년 09월 12일  내야수(우투좌타)  사당초-중앙중-안산공고-원광대-KIA-삼성-상무  14000만원
# 397   양현  39.0  1992년 08월 23일   투수(우언우타)        영랑초-한밭중-대전고-두산-상무-넥센   3000만원
# 295   보어  44.0  1988년 05월 28일  내야수(우투좌타)                         NaN      NaN
# 851  페레즈  14.0  1991년 03월 26일  내야수(우투우타)                         NaN      NaN
#
# ...

# %%
kbo['생년월일'][0][:4]
# Out:
# '1992'

# %%
#kbo['체중'] = kbo ['체중'].apply(lambda x: int(x.replace('kg', '')))
kbo['나이'] = kbo['생년월일'].apply(lambda x: (2021-int(x[:4])))

# %%
kbo
# Out:
#      선수명   등번호           생년월일        포지션                    경력    입단 계약금  \
# 0    강동연  21.0  1992년 12월 18일   투수(우투우타)  진북초-덕수중-유신고-두산-상무-두산       NaN
# 1    강진성  49.0  1993년 10월 19일  내야수(우투우타)     가동초-잠신중-경기고-NC-경찰    7000만원
# 2    강태경  78.0  2001년 07월 26일   투수(우투좌타)           양덕초-잠실중-배명고    7000만원
# 3    구창모  59.0  1997년 02월 17일   투수(좌투좌타)        천안남산초-덕수중-울산공고   15000만원
# 4    권법수  65.0  1997년 04월 05일  외야수(우투우타)          선학초-재능중-제물포고    5000만원
# ..   ...   ...            ...        ...                   ...       ...
# 852  하주석  16.0  1994년 02월 25일  내야수(우투좌타)     강남초-덕수중-신일고-한화-상무   30000만원
# 853  한승주  59.0  2001년 03월 17일   투수(우투우타)         부산수영초-대천중-부산고   11000만원
# 854  허관회  26.0  1999년 02월 12일   포수(우투우타)   경동초(의정부리틀)-건대부중-경기고    3000만원
# 855  황영국  60.0  1995년 12월 26일   투수(좌투좌타)   청주우암초-청주중-청주고-한화-경찰   20000만원
# 856   힐리   NaN  1992년 01월 10일  내야수(우투우타)       미국 Oregon(대)-한화  300000달러
#
#            연봉                지명순위  입단년도   신장   체중        BMI  나이
# ...

# %%
kbo['나이']
# Out:
# 0      29
# 1      28
# 2      20
# 3      24
# 4      24
#        ..
# 852    27
# 853    20
# 854    22
# 855    26
# 856    29
# Name: 나이, Length: 857, dtype: int64

# %%
kbo['연령대'] = kbo['나이'].apply(lambda x: str(x//10*10)+'대')

# %%
kbo
# Out:
#      선수명   등번호           생년월일        포지션                    경력    입단 계약금  \
# 0    강동연  21.0  1992년 12월 18일   투수(우투우타)  진북초-덕수중-유신고-두산-상무-두산       NaN
# 1    강진성  49.0  1993년 10월 19일  내야수(우투우타)     가동초-잠신중-경기고-NC-경찰    7000만원
# 2    강태경  78.0  2001년 07월 26일   투수(우투좌타)           양덕초-잠실중-배명고    7000만원
# 3    구창모  59.0  1997년 02월 17일   투수(좌투좌타)        천안남산초-덕수중-울산공고   15000만원
# 4    권법수  65.0  1997년 04월 05일  외야수(우투우타)          선학초-재능중-제물포고    5000만원
# ..   ...   ...            ...        ...                   ...       ...
# 852  하주석  16.0  1994년 02월 25일  내야수(우투좌타)     강남초-덕수중-신일고-한화-상무   30000만원
# 853  한승주  59.0  2001년 03월 17일   투수(우투우타)         부산수영초-대천중-부산고   11000만원
# 854  허관회  26.0  1999년 02월 12일   포수(우투우타)   경동초(의정부리틀)-건대부중-경기고    3000만원
# 855  황영국  60.0  1995년 12월 26일   투수(좌투좌타)   청주우암초-청주중-청주고-한화-경찰   20000만원
# 856   힐리   NaN  1992년 01월 10일  내야수(우투우타)       미국 Oregon(대)-한화  300000달러
#
#            연봉                지명순위  입단년도   신장   체중        BMI  나이  연령대
# ...

# %%
kbo['연령대'].value_counts()
# Out:
# 20대    572
# 30대    217
# 10대     65
# 40대      3
# Name: 연령대, dtype: int64

# %%
kbo[kbo['연령대'] == '40대']
# Out:
#      선수명   등번호           생년월일        포지션                             경력  \
# 226  유한준  61.0  1981년 07월 01일  외야수(우투우타)  부천신흥초-부천중-유신고-동국대-현대-우리-상무-넥센
# 314  이성우   4.0  1981년 09월 01일   포수(우투우타)      백운초-청원중-성남서고-상무-SK-KIA-SK
# 560  송승준  21.0  1980년 06월 29일   투수(우투우타)             하단초-경남중-경남고-(퍼시픽대)
#
#       입단 계약금       연봉                지명순위   입단년도   신장   체중        BMI  나이  연령대
# 226   6000만원  50000만원  00 현대 2차 3라운드 20순위   04현대  186   97  28.037923  40  40대
# 314      NaN   8000만원          00 LG 육성선수   03상무  180   91  28.086420  40  40대
# 560  20000만원   5000만원      07 해외진출선수 특별지명  99보스턴  184  106  31.309074  41  40대

# %%
kbo.groupby('포지션')['신장'].mean().sort_values()
# Out:
# 포지션
# 투수(우언좌타)     178.000000
# 내야수(우투좌타)    178.196970
# 외야수(좌투좌타)    178.823529
# 내야수(우투우타)    179.206612
# 포수(우투좌타)     180.000000
# 포수(우투우타)     180.476923
# 외야수(우투좌타)    180.812500
# 외야수(우투양타)    181.500000
# 외야수(우투우타)    182.645161
# 투수(좌투좌타)     183.182692
# 투수(우언우타)     183.548387
# 내야수(우투양타)    184.000000
# 내야수(좌투좌타)    184.333333
# 투수(좌언좌타)     185.000000
# 투수(우투우타)     185.007547
# 투수(우투좌타)     185.964286
# 투수(우투양타)     186.000000
# 투수(좌투우타)     186.666667
# 투수(우언양타)     188.000000
# Name: 신장, dtype: float64

# %%
b = kbo.groupby('포지션', as_index=False)[['신장']].mean()

# %%
b.sort_values(by=['신장'])
# Out:
#           포지션          신장
# 10   투수(우언좌타)  178.000000
# 2   내야수(우투좌타)  178.196970
# 7   외야수(좌투좌타)  178.823529
# 1   내야수(우투우타)  179.206612
# 18   포수(우투좌타)  180.000000
# 17   포수(우투우타)  180.476923
# 6   외야수(우투좌타)  180.812500
# 4   외야수(우투양타)  181.500000
# 5   외야수(우투우타)  182.645161
# 16   투수(좌투좌타)  183.182692
# 9    투수(우언우타)  183.548387
# 0   내야수(우투양타)  184.000000
# 3   내야수(좌투좌타)  184.333333
# 14   투수(좌언좌타)  185.000000
# 12   투수(우투우타)  185.007547
# 13   투수(우투좌타)  185.964286
# 11   투수(우투양타)  186.000000
# 15   투수(좌투우타)  186.666667
# 8    투수(우언양타)  188.000000

# %%
kbo.groupby('포지션', as_index=False)[['신장']].agg(['max', 'min', 'mean', 'median', 'std'])
# Out:
#             신장
#            max  min        mean median        std
# 포지션
# 내야수(우투양타)  185  183  184.000000  184.0   1.414214
# 내야수(우투우타)  196    0  179.206612  180.0  17.116716
# 내야수(우투좌타)  193    0  178.196970  182.0  22.849487
# 내야수(좌투좌타)  188  178  184.333333  185.0   3.464102
# 외야수(우투양타)  183  180  181.500000  181.5   2.121320
# 외야수(우투우타)  196  173  182.645161  183.0   4.516261
# 외야수(우투좌타)  190  170  180.812500  181.0   5.257846
# 외야수(좌투좌타)  188  163  178.823529  178.5   4.569136
# 투수(우언양타)   191  185  188.000000  188.0   4.242641
# 투수(우언우타)   193  175  183.548387  184.0   3.810850
# 투수(우언좌타)   178  178  178.000000  178.0        NaN
# 투수(우투양타)   188  184  186.000000  186.0   2.828427
# 투수(우투우타)   198  173  185.007547  185.0   4.525176
# 투수(우투좌타)   193  178  185.964286  186.5   3.939187
# 투수(좌언좌타)   185  185  185.000000  185.0        NaN
# 투수(좌투우타)   190  182  186.666667  188.0   4.163332
# 투수(좌투좌타)   196  173  183.182692  183.0   4.337160
# ...

# %%
kbo.groupby('포지션', as_index=False)[['신장']].agg(['max'])
# Out:
#             신장
#            max
# 포지션
# 내야수(우투양타)  185
# 내야수(우투우타)  196
# 내야수(우투좌타)  193
# 내야수(좌투좌타)  188
# 외야수(우투양타)  183
# 외야수(우투우타)  196
# 외야수(우투좌타)  190
# 외야수(좌투좌타)  188
# 투수(우언양타)   191
# 투수(우언우타)   193
# 투수(우언좌타)   178
# 투수(우투양타)   188
# 투수(우투우타)   198
# 투수(우투좌타)   193
# 투수(좌언좌타)   185
# 투수(좌투우타)   190
# 투수(좌투좌타)   196
# 포수(우투우타)   187
# 포수(우투좌타)   185

# %%
kbo.groupby(['포지션', '연령대'])[['신장']].agg(['max', 'min', 'mean', 'median', 'std', 'count'])
# Out:
#                 신장
#                max  min        mean median        std count
# 포지션       연령대
# 내야수(우투양타) 10대  185  185  185.000000  185.0        NaN     1
#           30대  183  183  183.000000  183.0        NaN     1
# 내야수(우투우타) 10대  187  178  182.111111  183.0   3.018462     9
#           20대  196  168  180.417722  180.0   4.722037    79
#           30대  194    0  175.515152  180.0  31.968853    33
# 내야수(우투좌타) 10대  190  176  183.333333  183.5   4.633213     6
#           20대  193  163  180.108696  181.0   5.313414    46
#           30대  187    0  169.714286  184.5  49.009306    14
# 내야수(좌투좌타) 20대  188  180  185.400000  187.0   3.209361     5
#           30대  187  178  183.000000  183.5   3.741657     4
# 외야수(우투양타) 30대  183  180  181.500000  181.5   2.121320     2
# 외야수(우투우타) 10대  191  173  183.000000  183.0   5.416026     7
#           20대  192  173  182.558824  183.0   4.150145    34
#           30대  196  173  182.500000  183.5   5.062764    20
# ...

# %%
kbo['생년월일']
# Out:
# 0      1992년 12월 18일
# 1      1993년 10월 19일
# 2      2001년 07월 26일
# 3      1997년 02월 17일
# 4      1997년 04월 05일
#            ...
# 852    1994년 02월 25일
# 853    2001년 03월 17일
# 854    1999년 02월 12일
# 855    1995년 12월 26일
# 856    1992년 01월 10일
# Name: 생년월일, Length: 857, dtype: object

# %%
from datetime import date, datetime, timedelta

# %%
c = datetime.now() - datetime.strptime('1992년 12월 18일', '%Y년 %m월 %d일')

# %%
c.days
# Out:
# 10491

# %%
(datetime.now() - datetime.strptime('1992년 12월 18일', '%Y년 %m월 %d일')).days
# Out:
# 10491

# %%
kbo['days'] = kbo['생년월일'].apply(lambda x : (datetime.now() - datetime.strptime(x, "%Y년 %m월 %d일")).days)

# %%
kbo.sort_values(by=['days'])
# Out:
#      선수명    등번호           생년월일        포지션                             경력  \
# 275  김유민  106.0  2003년 01월 18일  내야수(우투우타)                    화곡초-영남중-덕수고
# 837  정민규   64.0  2003년 01월 10일  내야수(우투우타)            광일초(부산서구리틀)-경남중-부산고
# 809   안진    4.0  2002년 11월 26일   포수(우투우타)                   인헌초-영남중-경기상고
# 113  박성재   98.0  2002년 11월 18일   포수(우투우타)                    가산초-개성중-부산고
# 775  김기중   15.0  2002년 11월 16일   투수(좌투좌타)                  의왕부곡초-매송중-유신고
# ..   ...    ...            ...        ...                            ...
# 571  이대호   10.0  1982년 06월 21일  내야수(우투우타)         부산수영초-대동중-경남고-(영남사이버대)
# 721  신재웅   11.0  1982년 03월 28일   투수(좌투좌타)  사파초-창원신월중-마산고-동의대-LG-두산-LG-SK
# 314  이성우    4.0  1981년 09월 01일   포수(우투우타)      백운초-청원중-성남서고-상무-SK-KIA-SK
# 226  유한준   61.0  1981년 07월 01일  외야수(우투우타)  부천신흥초-부천중-유신고-동국대-현대-우리-상무-넥센
# 560  송승준   21.0  1980년 06월 29일   투수(우투우타)             하단초-경남중-경남고-(퍼시픽대)
#
#       입단 계약금       연봉                지명순위   입단년도   신장   체중        BMI  나이  \
# ...

# %%
kbo_salary = kbo[kbo['연봉'].isnull() == False].copy()

# %%
kbo_salary.shape[1]
# Out:
# 15

# %%
import requests

# %%
def exchange(currency = "usd", date_ = "2021-07-23"):
    url = "https://kebhana.com/cms/rate/wpfxd651_01i_01.do"
    payload = {"ajax": "true",
            "curCd": "",
            "tmpInqStrDt": "2021-09-06",
            "pbldDvCd": "0",
            "pbldSqn": "",
            "hid_key_data": "",
            "inqStrDt": "20210906",
            "inqKindCd": "1",
            "hid_enc_data": "",
            "requestTarget": "searchContentDiv"}
    payload['tmpInqStrDt'] = date_
    payload['inqStrDt'] = date_.replace("-", "")
    r = requests.post(url, data=payload)
    a = pd.read_html(r.text)[0]
    a.columns = ["_".join(set(x)) for x in a.columns]
    return a[a['통화'].str.contains(currency.upper())]['매매기준율'].values[0]

# %%
exchange('eur', '2021-09-08')
# Out:
# 1380.49

# %%
[exchange('eur', str(x)[:10]) for x in pd.date_range('2021-01-01', '2021-09-08')]
# Out:
# [1336.17,
#  1336.17,
#  1336.17,
#  1330.77,
#  1337.67,
#  1340.69,
#  1337.92,
#  1336.23,
#  1336.23,
#  1336.23,
#  1335.83,
#  1334.85,
#  1335.87,
#  1333.23,
#  1333.03,
#  1333.03,
#  1333.03,
#  1335.82,
#  1337.77,
#  1335.13,
#  1336.45,
#  1344.95,
#  1344.95,
#  1344.95,
#  1339.81,
#  1340.75,
#  1340.64,
#  1353.39,
#  1355.75,
#  1355.75,
#  1355.75,
#  1352.19,
#  1343.27,
#  1341.38,
#  1340.47,
#  1345.34,
#  1345.34,
#  1345.34,
#  1348.79,
#  1347.67,
#  1342.35,
#  1342.35,
#  1342.35,
#  1342.35,
#  1342.35,
#  1337.72,
#  1340.69,
#  1336.64,
#  1335.76,
#  1340.97,
#  1340.97,
#  1340.97,
#  1347.69,
#  1350.69,
#  1348.49,
#  1355.75,
#  1364.04,
#  1364.04,
#  1364.04,
#  1364.04,
#  1352.1,
#  1356.32,
#  1355.23,
#  1347.12,
#  1347.12,
#  1347.12,
#  1351.83,
#  1354.87,
#  1358.41,
#  1355.41,
#  1354.71,
#  1354.71,
#  1354.71,
#  1352.32,
#  1350.38,
#  1345.4,
#  1343.36,
#  1344.19,
#  1344.19,
#  1344.19,
#  1344.29,
#  1343.32,
#  1338.73,
# ...
